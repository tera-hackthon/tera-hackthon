# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

import datainfos
import utils

# %matplotlib inline

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

sns.set_style('whitegrid')

plt.rcParams['figure.figsize'] = (18.0, 12.0)

# %%
carac = pd.read_csv("dataset/caracteristics.csv", encoding="latin-1")
places = pd.read_csv("dataset/places.csv", encoding="utf-8")
users = pd.read_csv("dataset/users.csv", encoding="utf-8")
vehicles = pd.read_csv("dataset/vehicles.csv", encoding="utf-8")
holi = pd.read_csv("dataset/holidays.csv", encoding="utf-8")
# Out:
# /usr/local/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /usr/local/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
carac = carac.rename(columns=datainfos.column_names)
places = places.rename(columns=datainfos.column_names)
users = users.rename(columns=datainfos.column_names)
vehicles = vehicles.rename(columns=datainfos.column_names)
holi = holi.rename(columns=datainfos.column_names)

# %%
carac.head()

# %%
def to_datetime(r):
    hhmm = "%04d" % (r['Hour'])
    hh = hhmm[:2]
    mm = hhmm[-2:]
    date = "2%03d/%02d/%02d %s:%s" % (r['Year'] , r['Month'], r['Day'], hh, mm)
    r = pd.to_datetime(date, format='%Y/%m/%d %H:%M')
    return r

def par(data):
    return data.apply(to_datetime, axis=1)
 
carac['DateTime'] = utils.parall_df(carac, par)

# %%
carac['Date'] = carac['DateTime'].dt.date
carac['Time'] = carac['DateTime'].dt.time
carac['Hour'] = carac['DateTime'].dt.hour
carac['Minute'] = carac['DateTime'].dt.minute
carac['Weekdays'] = carac['DateTime'].dt.dayofweek # Monday=0, Sunday=6

# %%
carac.head()

# %%
holi.head()

# %%
from datetime import timedelta
period = 7
delta = timedelta(days=period)

holi['ds'] = pd.to_datetime(holi['ds'])
holi_range = pd.DataFrame()

for index, row in holi.iterrows():
    date = pd.to_datetime(row['ds'])
    dates = pd.date_range(date - delta, periods=1+(period*2), freq='d')
    days = dates.day
    months = dates.month
    holiday_ranges = dates - date
    df = pd.DataFrame({'Month': months, 'Day': days, 'HolidayRange': holiday_ranges.days})
    df['Holiday'] = row['holiday']
    holi_range = pd.concat([holi_range, df], ignore_index=True)

# %%
holi_range.head()

# %%
places.head()

# %%
users.head()
# Out:
#         Num_Acc  place  catu  grav  sexe  trajet  secu  locp  actp  etatp  an_nais num_veh
# 0  201600000001    1.0     1     1     2     0.0  11.0   0.0   0.0    0.0   1983.0     B02
# 1  201600000001    1.0     1     3     1     9.0  21.0   0.0   0.0    0.0   2001.0     A01
# 2  201600000002    1.0     1     3     1     5.0  11.0   0.0   0.0    0.0   1960.0     A01
# 3  201600000002    2.0     2     3     1     0.0  11.0   0.0   0.0    0.0   2000.0     A01
# 4  201600000002    3.0     2     3     2     0.0  11.0   0.0   0.0    0.0   1962.0     A01

# %%
users['Driver'] = np.where(users['UserCategory'] == 1, True, False)
users['DriverSex'] = np.where(users['Driver'], users['Sex'], None)
users['DriverSeverity'] = users['Severity'][users['Driver']]
users['DriverSafetyEquipment'] = users['SafetyEquipment'][users['Driver']]
users['DriverBirthday'] = users['an_nais'][users['Driver']]
users['Passenger'] = np.where(users['UserCategory'] == 2, True, False)
users['Pedestrian'] = np.where(users['UserCategory'] == 3, True, False)
# temp_users['Pedestrian_'] = np.where(users['UserCatagory'] == 3, 1, 0)

users[users['UserCategory'] == 1]
# Out:
#            AccidentID  Place  UserCategory  Severity  Sex  trajet  SafetyEquipment  Locationofpedestrian  Actionofpedestrian  PedestrianGroup  an_nais num_veh  Driver DriverSex  DriverSeverity  DriverSafetyEquipment  DriverBirthday  Passenger  Pedestrian
# 0        201600000001    1.0             1         1    2     0.0             11.0                   0.0                 0.0              0.0   1983.0     B02    True         2             1.0                   11.0          1983.0      False       False
# 1        201600000001    1.0             1         3    1     9.0             21.0                   0.0                 0.0              0.0   2001.0     A01    True         1             3.0                   21.0          2001.0      False       False
# ...

# %%
users.dtypes
# Out:
# AccidentID                 int64
# Place                    float64
# UserCategory               int64
# Severity                   int64
# Sex                        int64
# trajet                   float64
# SafetyEquipment          float64
# Locationofpedestrian     float64
# Actionofpedestrian       float64
# PedestrianGroup          float64
# an_nais                  float64
# num_veh                   object
# Driver                      bool
# DriverSex                 object
# DriverSeverity           float64
# DriverSafetyEquipment    float64
# DriverBirthday           float64
# Passenger                   bool
# Pedestrian                  bool
# dtype: object

# %%
group_users = users.groupby(['AccidentID'])

# %%
def agg_severity(r):
    if not r.isin([4.0]).empty :
        return 4
    return 0

agg_users = group_users.agg({
#     'Driver': 'sum',
    'DriverSeverity': agg_severity,
#     'Passenger': 'sum',
#     'Pedestrian': 'sum',
})
agg_users
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-74-88abc90c2544> in <module>()
#       6 agg_users = group_users.agg({
#       7 #     'Driver': 'sum',
# ----> 8     'DriverSeverity': agg_severity,
#       9 #     'Passenger': 'sum',
#      10 #     'Pedestrian': 'sum',
#
# /usr/local/anaconda3/lib/python3.6/site-packages/pandas/core/groupby.py in aggregate(self, arg, *args, **kwargs)
#    4289         versionadded=''))
#    4290     def aggregate(self, arg, *args, **kwargs):
# -> 4291         return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#    4292
#    4293     agg = aggregate
#
# /usr/local/anaconda3/lib/python3.6/site-packages/pandas/core/groupby.py in aggregate(self, arg, *args, **kwargs)
#    3722
#    3723         _level = kwargs.pop('_level', None)
# -> 3724         result, how = self._aggregate(arg, _level=_level, *args, **kwargs)
# ...

# %%
users[users['AccidentID'] == 200500000004]
# Out:
#            AccidentID  Place  UserCategory  Severity  Sex  trajet  SafetyEquipment  Locationofpedestrian  Actionofpedestrian  PedestrianGroup  an_nais num_veh  Driver DriverSex  DriverSeverity  DriverSafetyEquipment  Passenger  Pedestrian  DriverBirthday
# 1678517  200500000004    1.0             1         3    1     5.0             11.0                   0.0                 0.0              0.0   1920.0     A01    True         1             3.0                   11.0          0           0          1920.0
# 1678518  200500000004    2.0             2         3    2     0.0             11.0                   0.0                 0.0              0.0   1923.0     A01   False      None             NaN                    NaN          1           0             NaN
# ...

# %%
vehicles[vehicles['AccidentID'] == 200500000004]
# Out:
#            AccidentID  senc  catv  occutc  obs  obsm  choc  manv num_veh
# 1283631  200500000004   0.0     7       0  0.0   2.0   1.0  13.0     A01
# 1283632  200500000004   0.0     7       0  0.0   2.0   0.0   1.0     B02
# 1283633  200500000004   0.0     7       0  0.0   2.0   8.0   1.0     C03

# %%
vehicles.head()
# Out:
#      AccidentID  senc  catv  occutc  obs  obsm  choc  manv num_veh
# 0  201600000001   0.0     7       0  0.0   0.0   1.0   1.0     B02
# 1  201600000001   0.0     2       0  0.0   0.0   7.0  15.0     A01
# 2  201600000002   0.0     7       0  6.0   0.0   1.0   1.0     A01
# 3  201600000003   0.0     7       0  0.0   1.0   6.0   1.0     A01
# 4  201600000004   0.0    32       0  0.0   0.0   1.0   1.0     B02

# %%
group_vehicles = vehicles.groupby(['AccidentID'])
group_vehicles.head()
# Out:
#            AccidentID  senc  catv  occutc   obs  obsm  choc  manv num_veh
# 0        201600000001   0.0     7       0   0.0   0.0   1.0   1.0     B02
# 1        201600000001   0.0     2       0   0.0   0.0   7.0  15.0     A01
# 2        201600000002   0.0     7       0   6.0   0.0   1.0   1.0     A01
# 3        201600000003   0.0     7       0   0.0   1.0   6.0   1.0     A01
# 4        201600000004   0.0    32       0   0.0   0.0   1.0   1.0     B02
# 5        201600000004   0.0     7       0   0.0   0.0   8.0  15.0     A01
# 6        201600000005   0.0    30       0   0.0   2.0   1.0  15.0     B02
# 7        201600000005   0.0     7       0   0.0   2.0   3.0   1.0     A01
# 8        201600000006   0.0     7       0   0.0   1.0   1.0   1.0     A01
# 9        201600000007   1.0    30       0   0.0   0.0   3.0  15.0     A01
# 10       201600000007   1.0     7       0   0.0   2.0   2.0  17.0     B02
# 11       201600000008   0.0     7       0   0.0   2.0   2.0   1.0     B02
# ...

# %%
agg_vehicles = group_users.agg({
    'Vehicles': 'count',
})
agg_vehicles
# Out:
# /usr/local/anaconda3/lib/python3.6/site-packages/pandas/core/groupby.py:4291: FutureWarning: using a dict with renaming is deprecated and will be removed in a future version
#   return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
c_h = pd.merge(carac, holi_range, on=['Month', 'Day'], how='left')

# %%
c_h_p = pd.merge(c_h, places, on='AccidentID')

# %%
c_h_p_u = pd.merge(c_h_p, agg_users, on='AccidentID')

# %%
c_h_p_u_v = pd.merge(c_h_p, agg_vehicles, on='AccidentID')

# %%
merged = c_h_p_u_v

# %%
merged.head()

# %%
merged = pd.merge(places, carac, on='Num_Acc')
merged = pd.merge(merged, vehicles, on='Num_Acc', how='outer')
merged = pd.merge(merged, users, on='Num_Acc', how='outer')

# %%
merged.to_csv('dataset/agg.csv.gz', compression='gzip', encoding='utf-8', index=False)
